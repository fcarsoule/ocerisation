# %% [markdown]
# <h1>Top 10 Classification - Modèle LeNet</h1>
# <br>

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !mkdir database
! mkdir database/ascii
! tar xzf drive/MyDrive/ocr/database/ascii.tgz -C database/ascii

! mkdir database/words
! tar xzf drive/MyDrive/ocr/database/words.tgz -C database/words

! mkdir database/images_test
! cp -r drive/MyDrive/ocr/database/images_test/* database/images_test/

! cp drive/MyDrive/ocr/src/streamlit/importation.py importation.py
! cp drive/MyDrive/ocr/src/streamlit/preprocessor_2.py preprocessor_2.py
! cp drive/MyDrive/ocr/src/streamlit/wsmodel.py wsmodel.py
! cp drive/MyDrive/ocr/src/streamlit/top10model.py top10model.py

! mkdir models
! cp drive/MyDrive/ocr/models/* models/

# %%
from  importation import Importation
from preprocessor import Preprocess
import top10model
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import cv2

# %%
#import importlib
#import sys
#importlib.reload(sys.modules['preprocessor_2'])

# %% [markdown]
# # Importation des données - preprocessing

# %%
imp = Importation('database')
df = imp.get_words().sample(frac=1, random_state=1).reset_index()

df.word_size = df.word_size.astype('float32')
print("Nombre d'enregistrements ", df.shape[0])


df = df[['file','label', 'word_size']]
df.info()
words_list = df[(df.word_size==3)|(df.word_size==4)].label.value_counts().head(10)
print("\nTop 10 mots 3 ou 4 lettres : \n")
print(words_list)

df = df[df.label.isin(words_list.index)]
encoder = LabelEncoder()
df["label_encoded"] = encoder.fit_transform(df.label)

df.head(20)

image_width = 128
image_height = 32
batch_size = 64
img_size = (image_width, image_height)
prepro = Preprocess(img_size, batch_size=batch_size, gaussianBlur=True)

df_train, df_valid, df_test = prepro.split_data(df, train_size=0.9)

x_train, y_train = df_train["file"].values, df_train["label_encoded"].values
x_test, y_test = df_test["file"].values, df_test["label_encoded"].values
x_valid, y_valid = df_valid["file"].values, df_valid["label_encoded"].values

train_ds = prepro.prepare_dataset_top10(x_train, y_train)
validation_ds = prepro.prepare_dataset_top10(x_valid, y_valid)
test_ds = prepro.prepare_dataset_top10(x_test, y_test)
# Out:
# Nombre d'enregistrements  96454
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96454 entries, 0 to 96453
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file       96454 non-null  object
#  1   label      96454 non-null  object
#  2   word_size  96454 non-null  float32
# dtypes: float32(1), object(2)
# memory usage: 1.8+ MB
#
# Top 10 mots 3 ou 4 lettres :
#
# the     4986
# and     2110
# was      970
# that     968
# for      718
# had      670
# with     645
# his      597
# The      548
# not      412
# Name: label, dtype: int64
# initialisation
# 2022-09-19 10:36:30.255885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.291320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.291553: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.292724: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-19 10:36:30.293007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.293200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.293378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.738366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.738596: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.738782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 10:36:30.738923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4347 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:29:00.0, compute capability: 7.5

# %% [markdown]
# # Chargement du modèle

# %%
#import importlib
#import sys
#importlib.reload(sys.modules['wsmodel']) 
image_width = 128
image_height = 32
num_classes = 10
train = False
model = top10model.create_model_lenet(image_width, image_height, num_classes)
#model = wsmodel.create_model_cnn(image_width, image_height, num_classes)
#model = wsmodel.create_model_dense(image_width, image_height, num_classes)
if train:
    opt = tf.keras.optimizers.Adam()
    model.compile(optimizer=opt, loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
model.summary()
# Out:
# Model: "LeNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  image (InputLayer)          [(None, 128, 32, 1)]      0
#
#  conv1 (Conv2D)              (None, 124, 28, 30)       780
#
#  max_pooling2d (MaxPooling2D  (None, 62, 14, 30)       0
#  )
#
#  dropout (Dropout)           (None, 62, 14, 30)        0
#
#  conv2 (Conv2D)              (None, 60, 12, 50)        13550
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 6, 50)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 6, 50)         0
#
#  flatten (Flatten)           (None, 9000)              0
#
#  dense1 (Dense)              (None, 128)               1152128
#
#  dense2 (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,167,748
# Trainable params: 1,167,748
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Entraînement du modèle

# %%
if train:
    epochs = 50
    training_history = model.fit(
        train_ds,
        validation_data=validation_ds,
        epochs=epochs,
        verbose=1
    )

    train_loss = training_history.history["loss"]
    val_loss = training_history.history["val_loss"]
    train_acc = training_history.history["accuracy"]
    val_acc = training_history.history["val_accuracy"]
    plt.figure(figsize=(12, 4))
    plt.subplot(121)
    plt.plot(train_loss)
    plt.plot(val_loss)
    plt.title('Model loss per epoch')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='right')

    plt.subplot(122)
    plt.plot(train_acc)
    plt.plot(val_acc)
    plt.title('Model accuracy per epoch')
    plt.ylabel('acc')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='right')
    model.save_weights("models/top10_lenet.h1")
else: 
    model.load_weights("models/top10_lenet.h1")
# Out:
# Epoch 1/50
# 2022-09-19 10:36:45.535397: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8302
# 178/178 [==============================] - 40s 213ms/step - loss: 1.5291 - accuracy: 0.5272 - val_loss: 1.1246 - val_accuracy: 0.6292
# Epoch 2/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.6633 - accuracy: 0.7903 - val_loss: 0.4983 - val_accuracy: 0.8621
# Epoch 3/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.3785 - accuracy: 0.8834 - val_loss: 0.3229 - val_accuracy: 0.9065
# Epoch 4/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.2553 - accuracy: 0.9240 - val_loss: 0.2535 - val_accuracy: 0.9160
# Epoch 5/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.1941 - accuracy: 0.9407 - val_loss: 0.2170 - val_accuracy: 0.9255
# Epoch 6/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.1511 - accuracy: 0.9533 - val_loss: 0.2072 - val_accuracy: 0.9319
# Epoch 7/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.1200 - accuracy: 0.9636 - val_loss: 0.2434 - val_accuracy: 0.9160
# Epoch 8/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0974 - accuracy: 0.9702 - val_loss: 0.2249 - val_accuracy: 0.9128
# Epoch 9/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.0830 - accuracy: 0.9747 - val_loss: 0.1875 - val_accuracy: 0.9382
# Epoch 10/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 0.9761 - val_loss: 0.1742 - val_accuracy: 0.9398
# Epoch 11/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0622 - accuracy: 0.9791 - val_loss: 0.1934 - val_accuracy: 0.9382
# Epoch 12/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.0516 - accuracy: 0.9835 - val_loss: 0.2189 - val_accuracy: 0.9255
# Epoch 13/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0457 - accuracy: 0.9852 - val_loss: 0.2117 - val_accuracy: 0.9398
# Epoch 14/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0419 - accuracy: 0.9862 - val_loss: 0.1984 - val_accuracy: 0.9382
# Epoch 15/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0343 - accuracy: 0.9893 - val_loss: 0.1999 - val_accuracy: 0.9445
# Epoch 16/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0300 - accuracy: 0.9908 - val_loss: 0.1646 - val_accuracy: 0.9398
# Epoch 17/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0281 - accuracy: 0.9914 - val_loss: 0.1937 - val_accuracy: 0.9414
# Epoch 18/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.1640 - val_accuracy: 0.9477
# Epoch 19/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.2089 - val_accuracy: 0.9477
# Epoch 20/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0223 - accuracy: 0.9929 - val_loss: 0.2125 - val_accuracy: 0.9493
# Epoch 21/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0235 - accuracy: 0.9930 - val_loss: 0.2415 - val_accuracy: 0.9334
# Epoch 22/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0273 - accuracy: 0.9911 - val_loss: 0.1791 - val_accuracy: 0.9461
# Epoch 23/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0201 - accuracy: 0.9939 - val_loss: 0.1991 - val_accuracy: 0.9429
# Epoch 24/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0212 - accuracy: 0.9937 - val_loss: 0.2215 - val_accuracy: 0.9334
# Epoch 25/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.1899 - val_accuracy: 0.9414
# Epoch 26/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.2037 - val_accuracy: 0.9477
# Epoch 27/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.1973 - val_accuracy: 0.9461
# Epoch 28/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.1903 - val_accuracy: 0.9509
# Epoch 29/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0194 - accuracy: 0.9942 - val_loss: 0.2248 - val_accuracy: 0.9493
# Epoch 30/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.1956 - val_accuracy: 0.9572
# Epoch 31/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.2659 - val_accuracy: 0.9350
# Epoch 32/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.1980 - val_accuracy: 0.9525
# Epoch 33/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0152 - accuracy: 0.9944 - val_loss: 0.2139 - val_accuracy: 0.9572
# Epoch 34/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.0097 - accuracy: 0.9973 - val_loss: 0.2245 - val_accuracy: 0.9525
# Epoch 35/50
# 178/178 [==============================] - 1s 7ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.2058 - val_accuracy: 0.9556
# Epoch 36/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 0.3052 - val_accuracy: 0.9493
# Epoch 37/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.2473 - val_accuracy: 0.9398
# Epoch 38/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.2590 - val_accuracy: 0.9445
# Epoch 39/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.3206 - val_accuracy: 0.9461
# Epoch 40/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.2608 - val_accuracy: 0.9429
# Epoch 41/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.2759 - val_accuracy: 0.9540
# Epoch 42/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0126 - accuracy: 0.9967 - val_loss: 0.2980 - val_accuracy: 0.9461
# Epoch 43/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.2751 - val_accuracy: 0.9509
# Epoch 44/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0139 - accuracy: 0.9952 - val_loss: 0.3663 - val_accuracy: 0.9382
# Epoch 45/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.2637 - val_accuracy: 0.9477
# Epoch 46/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.2424 - val_accuracy: 0.9493
# Epoch 47/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.2807 - val_accuracy: 0.9382
# Epoch 48/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.2806 - val_accuracy: 0.9334
# Epoch 49/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.2201 - val_accuracy: 0.9509
# Epoch 50/50
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.2490 - val_accuracy: 0.9525

# %% [markdown]
# # Prédictions

# %%
# Création d'un dataset pour une image unique
def get_ds(img_path, encoded_label):
    x = np.array([img_path])
    y = np.array([encoded_label])
    ds = prepro.prepare_dataset_top10(x, y)
    return ds

def get_prediction(ds):
    inputs = []
    outputs = []
    for batch in ds:
        label_encode = batch[1] 
        #batch_images = tf.transpose(batch[0], [0,2,1,3])
        batch_images = batch[0]
        preds = model.predict(batch_images, verbose=0)
        #print(np.argmax(preds.tolist()[0]), label_encode)
        outputs += [np.argmax(v) for v in preds.tolist()]
        inputs += label_encode.numpy().tolist()
        #output += preds.tolist()
    return outputs, inputs


files = []
labels = []
predictions = []
distances = []
df_predict = df_test
for i in np.random.choice(np.arange(0, len(df_predict)), size=3):  
  label = df_predict.iloc[i].label
  encoded_label = df_predict.iloc[i].label_encoded
  img_path = df_predict.iloc[i].file
  ds = get_ds(img_path, encoded_label)
  prediction, inputs= get_prediction(ds)

  image = cv2.imread(img_path)
  plt.figure(figsize=(10,3))
  plt.imshow(image, cmap='gray')
  plt.xticks([])
  plt.yticks([])
  plt.show()
  print(f"Label     : {label}")
  #print("encoded label: ", encoded_label)
  #print("Input: ", inputs)
  print("Prédiction: ",encoder.inverse_transform(prediction)[0])
# Out:
# Label     : that
# Prédiction:  that
# Label     : the
# Prédiction:  the
# Label     : The
# Prédiction:  The

# %% [markdown]
# ## Prédiction sur l'ensemble de test

# %%
ds = test_ds
outputs,inputs = get_prediction(ds)

        
df_result = pd.DataFrame({'file' : df_test.file,
                          'label': df_test.label,
                          'label_encoded' : df_test.label_encoded,
                          'prediction' : outputs,
                         })

df_result['label_decoded'] = encoder.inverse_transform(df_result['prediction'])
acc_test = df_result[df_result['label_encoded']==df_result["prediction"]].shape[0]/df_result.shape[0]
print("Accuracy sur l'ensemble de test :", acc_test)

df_result.drop("file", axis=1).head(20)
# Out:
# Accuracy sur l'ensemble de test : 0.9636075949367089
#       label  label_encoded  prediction label_decoded
# 91930   the              7           7           the
# 91940   not              5           5           not
# 91942   the              7           7           the
# 91946   the              7           7           the
# 91949   for              2           2           for
# 91961   was              8           8           was
# 91974   for              2           2           for
# 91976   the              7           7           the
# 91983   the              7           7           the
# 91987   was              8           8           was
# 91997   and              1           1           and
# 92001   the              7           7           the
# 92002   had              3           3           had
# 92018   and              1           1           and
# 92024   not              5           5           not
# 92031   the              7           7           the
# 92034  that              6           6          that
# 92040   not              5           5           not
# 92042   the              7           7           the
# 92056   the              7           7           the

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import itertools

true_labels = df_result.label
pred_labels = df_result.label_decoded


print("Accuracy : ", round(accuracy_score(true_labels, pred_labels),2))
print("Classification report :\n", classification_report(true_labels, pred_labels))

cnf_matrix = confusion_matrix(true_labels, pred_labels)

plt.figure(figsize=(10,10))

plt.imshow(cnf_matrix, interpolation='nearest',cmap='Blues')
plt.title("Matrice de confusion")
plt.colorbar()
tick_marks = np.arange(num_classes)
classes = encoder.inverse_transform(tick_marks)
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
    plt.text(j, i, cnf_matrix[i, j],
             horizontalalignment = "center",
             color = "white" if cnf_matrix[i, j] > ( cnf_matrix.max() / 2) else "black")

plt.ylabel('Vrais labels')
plt.xlabel('Labels prédits')
plt.show()

for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
    if(cnf_matrix[i,j] >15 and i!=j):
        print("Le mot '{0}' a souvent été pris pour le mot '{1}'".format(classes[i],classes[j]))
# Out:
# Accuracy :  0.96
# Classification report :
#                precision    recall  f1-score   support
#
#          The       0.91      0.97      0.94        30
#          and       0.93      0.97      0.95       104
#          for       1.00      0.96      0.98        28
#          had       0.93      0.87      0.90        31
#          his       0.97      0.97      0.97        35
#          not       0.95      0.86      0.90        22
#         that       1.00      0.92      0.96        51
#          the       0.99      0.99      0.99       270
#          was       0.87      0.98      0.92        41
#         with       1.00      0.95      0.97        20
#
#     accuracy                           0.96       632
#    macro avg       0.95      0.94      0.95       632
# weighted avg       0.97      0.96      0.96       632
